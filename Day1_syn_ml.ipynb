# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("CardioGoodFitness-2.csv")

# %%
df.head()
# Out:
#   Product   Age  Gender  Education MaritalStatus  Usage  Fitness   Income  \
# 0   TM195  18.0    Male       14.0        Single      3      4.0  29562.0
# 1   TM195  19.0    Male       15.0        Single      2      3.0  31836.0
# 2   TM195  19.0  Female        NaN     Partnered      4      3.0  30699.0
# 3   TM195  19.0    Male       12.0        Single      3      3.0  32973.0
# 4   TM195  20.0    Male       13.0     Partnered      4      2.0  35247.0
#
#    Miles
# 0  112.0
# 1   75.0
# 2   66.0
# 3   85.0
# 4   47.0

# %%
df.tail()
# Out:
#     Product   Age Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 175   TM798  40.0   Male       21.0        Single      6      5.0   83416.0
# 176   TM798  42.0   Male       18.0        Single      5      4.0   89641.0
# 177   TM798  45.0   Male       16.0        Single      5      5.0   90886.0
# 178   TM798  47.0   Male       18.0     Partnered      4      5.0  104581.0
# 179   TM798  48.0   Male       18.0     Partnered      4      5.0   95508.0
#
#      Miles
# 175  200.0
# 176  200.0
# 177  160.0
# 178  120.0
# 179  180.0

# %%
df.head(10)
# Out:
#   Product   Age  Gender  Education MaritalStatus  Usage  Fitness   Income  \
# 0   TM195  18.0    Male       14.0        Single      3      4.0  29562.0
# 1   TM195  19.0    Male       15.0        Single      2      3.0  31836.0
# 2   TM195  19.0  Female        NaN     Partnered      4      3.0  30699.0
# 3   TM195  19.0    Male       12.0        Single      3      3.0  32973.0
# 4   TM195  20.0    Male       13.0     Partnered      4      2.0  35247.0
# 5   TM195  20.0  Female       14.0     Partnered      3      3.0  32973.0
# 6   TM195  21.0  Female       14.0     Partnered      3      3.0  35247.0
# 7     NaN  21.0    Male       13.0        Single      3      3.0  32973.0
# 8   TM195  21.0    Male       15.0        Single      5      4.0  35247.0
# 9   TM195  21.0  Female       15.0     Partnered      2      3.0      NaN
#
#    Miles
# 0  112.0
# 1   75.0
# 2   66.0
# 3   85.0
# 4   47.0
# 5   66.0
# 6   75.0
# 7   85.0
# 8  141.0
# 9   85.0

# %%
df.tail(15)
# Out:
#     Product   Age  Gender  Education MaritalStatus  Usage  Fitness    Income  \
# 165   TM798  29.0    Male       18.0        Single      5      5.0   52290.0
# 166   TM798  29.0    Male       14.0     Partnered      7      5.0   85906.0
# 167   TM798  30.0  Female       16.0     Partnered      6      5.0   90886.0
# 168   TM798  30.0    Male       18.0     Partnered      5      4.0  103336.0
# 169   TM798  30.0    Male       18.0     Partnered      5      5.0   99601.0
# 170   TM798  31.0    Male       16.0     Partnered      6      5.0   89641.0
# 171   TM798  33.0  Female       18.0     Partnered      4      5.0   95866.0
# 172   TM798  34.0    Male       16.0        Single      5      5.0   92131.0
# 173   TM798  35.0    Male       16.0     Partnered      4      5.0   92131.0
# 174   TM798  38.0    Male       18.0     Partnered      5      5.0  104581.0
# 175   TM798  40.0    Male       21.0        Single      6      5.0   83416.0
# ...

# %%
df.sample()
# Out:
#   Product   Age Gender  Education MaritalStatus  Usage  Fitness   Income  \
# 3   TM195  19.0   Male       12.0        Single      3      3.0  32973.0
#
#    Miles
# 3   85.0

# %%
df.sample(10)
# Out:
#     Product   Age  Gender  Education MaritalStatus  Usage  Fitness   Income  \
# 179   TM798  48.0    Male       18.0     Partnered      4      5.0  95508.0
# 1     TM195  19.0    Male       15.0        Single      2      3.0  31836.0
# 83    TM498  20.0    Male       14.0        Single      3      3.0  38658.0
# 154   TM798  25.0    Male       18.0     Partnered      6      4.0  70966.0
# 62    TM195  34.0  Female       16.0        Single      2      2.0  52302.0
# 106   TM498  25.0  Female       14.0        Single      2      2.0  45480.0
# 177   TM798  45.0    Male       16.0        Single      5      5.0  90886.0
# 35    TM195  26.0  Female       16.0     Partnered      4      3.0  52302.0
# 25    TM195  24.0    Male       13.0     Partnered      3      2.0  42069.0
# 23    TM195  24.0  Female       16.0     Partnered      5      5.0  44343.0
#
#      Miles
# 179  180.0
# 1     75.0
# 83    95.0
# 154  180.0
# 62    66.0
# 106   42.0
# 177  160.0
# 35   113.0
# 25    47.0
# ...

# %%
df.shape
# Out:
# (180, 9)

# %%
df.dtypes
# Out:
# Product           object
# Age              float64
# Gender            object
# Education        float64
# MaritalStatus     object
# Usage              int64
# Fitness          float64
# Income           float64
# Miles            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        178 non-null    object
#  1   Age            178 non-null    float64
#  2   Gender         180 non-null    object
#  3   Education      179 non-null    float64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        178 non-null    float64
#  7   Income         178 non-null    float64
#  8   Miles          176 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  178.000000  179.000000  180.000000  178.000000     178.000000
# mean    28.853933   15.581006    3.455556    3.314607   53856.870787
# std      6.951894    1.617279    1.084797    0.963697   16542.805624
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44343.000000
# 50%     26.500000   16.000000    3.000000    3.000000   51165.000000
# 75%     33.000000   16.000000    4.000000    4.000000   58972.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  176.000000
# mean   103.732955
# std     52.300366
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    120.000000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      178  178.000000    180  179.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        79         NaN    104         NaN           107         NaN
# mean       NaN   28.853933    NaN   15.581006           NaN    3.455556
# std        NaN    6.951894    NaN    1.617279           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.500000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   178.000000     178.000000  176.000000
# ...

# %%
sns.countplot(x="Product",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x="Fitness",data=df)
# Out:
# <Axes: xlabel='Fitness', ylabel='count'>

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
sns.countplot(x="Product",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x="Product",hue="MaritalStatus",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.boxplot(x="Age",data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x="Education",data=df)
# Out:
# <Axes: xlabel='Education'>

# %%
sns.boxplot(x="Fitness",data=df)
# Out:
# <Axes: xlabel='Fitness'>

# %%
sns.boxplot(x="Product",y="Age",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
sns.boxplot(x="Product",y="Education",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Education'>

# %%
sns.boxplot(x="Product",y="Income",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
sns.violinplot(x="Product",y="Income",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
sns.swarmplot(x="Product",y="Income",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
sns.boxplot(x="Product",y="Income",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Product', ylabel='Income'>

# %%
sns.swarmplot(x="Product",y="Education",hue="Gender",data=df)
# Out:
# C:\Users\Premalatha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Premalatha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Product', ylabel='Education'>
# C:\Users\Premalatha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 38.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Premalatha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 25.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df)

# %%
df.corr(numeric_only=True)
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.268357  0.025897  0.062477  0.505273  0.063481
# Education  0.268357   1.000000  0.399240  0.410121  0.624554  0.308508
# Usage      0.025897   0.399240  1.000000  0.671330  0.518293  0.759583
# Fitness    0.062477   0.410121  0.671330  1.000000  0.533943  0.785835
# Income     0.505273   0.624554  0.518293  0.533943  1.000000  0.543000
# Miles      0.063481   0.308508  0.759583  0.785835  0.543000  1.000000
